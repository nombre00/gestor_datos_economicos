# %%
import pandas as pd

xls = pd.ExcelFile(r"D:\yo\programacion\proyectos practicando\gestor_datos_economicos\datasets\raw\Composicion de la Deuda (sep-2025).xlsx")
print(xls.sheet_names)
# Out:
# ['Moneda', 'Acreedor', 'Legislación']

# %%
df_moneda = pd.read_excel(xls, sheet_name="Moneda", header=None)
df_moneda.head(10)
# Out:
#                           0       1       2           3           4   \
# 0                        NaN    2005    2006        2007        2008
# 1                Dólares USA  6567.5    5031      3477.3      2770.8
# 2  Unidades de Fomento Chile  2652.7  2464.7      3091.4      3811.8
# 3                      Pesos       -       -  342.866363  588.132441
# 4       Unidad de Cuenta BID    57.8    54.9        52.6        51.6
# 5     Unidad de Canasta BIRF       -       -           -           -
# 6                Yen Japonés     0.1       -           -           -
# 7                      Euros    91.2     114       125.1       111.7
# 8               Marco Alemán       -       -           -           -
# 9                      Otras       2     1.9         4.7    0.967559
#
#           5        6        7             8             9   ...            12  \
# 0       2009     2010     2011          2012          2013  ...          2016
# ...
