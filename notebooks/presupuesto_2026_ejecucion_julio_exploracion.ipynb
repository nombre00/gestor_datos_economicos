# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd

df = pd.read_csv("../datasets/raw/presupuesto_2026_ejecucion_hasta_julio.csv")

df.head()
# Out:
#    _id   Ano    Mes   Moneda  Subtitulo                 Nombre Subtitulo  \
# 0    1  2026  Julio  Dolares          1                        IMPUESTOS
# 1    2  2026  Julio  Dolares          6           RENTAS DE LA PROPIEDAD
# 2    3  2026  Julio  Dolares          7            INGRESOS DE OPERACIÓN
# 3    4  2026  Julio  Dolares          8        OTROS INGRESOS CORRIENTES
# 4    5  2026  Julio  Dolares         10  VENTA DE ACTIVOS NO FINANCIEROS
#
#   Monto Ley Inicial Monto Ley Vigente a Julio
# 0           308.200                   308.200
# 1         1.797.058                 1.797.058
# 2             5.239                     5.239
# 3            16.552                    16.552
# 4                10                        10

# %%
df.shape
# Out:
# (45, 8)

# %%
df.columns
# Out:
# Index(['_id', 'Ano', 'Mes', 'Moneda', 'Subtitulo', 'Nombre Subtitulo',
#        'Monto Ley Inicial', 'Monto Ley Vigente a Julio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        45 non-null     int64
#  1   Ano                        45 non-null     int64
#  2   Mes                        45 non-null     object
#  3   Moneda                     45 non-null     object
#  4   Subtitulo                  45 non-null     int64
#  5   Nombre Subtitulo           45 non-null     object
#  6   Monto Ley Inicial          45 non-null     object
#  7   Monto Ley Vigente a Julio  45 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 2.9+ KB

# %%
df.isna().sum()
# Out:
# _id                          0
# Ano                          0
# Mes                          0
# Moneda                       0
# Subtitulo                    0
# Nombre Subtitulo             0
# Monto Ley Inicial            0
# Monto Ley Vigente a Julio    0
# dtype: int64

# %%
df.describe()
# Out:
#              _id     Ano  Subtitulo
# count  45.000000    45.0  45.000000
# mean   23.000000  2026.0  19.155556
# std    13.133926     0.0  10.563564
# min     1.000000  2026.0   1.000000
# 25%    12.000000  2026.0  10.000000
# 50%    23.000000  2026.0  21.000000
# 75%    34.000000  2026.0  29.000000
# max    45.000000  2026.0  35.000000

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(14, 8), bins=10)
plt.tight_layout()
plt.show()
